# %%
a = 5
a
# Out:
# 5

# %%
import sys 
sys.version
# Out:
# '3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:03:56) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# ## Work with Number

# %%
5
# Out:
# 5

# %%
3
# Out:
# 3

# %%
3 + 5
# Out:
# 8

# %%
10 - 5
# Out:
# 5

# %%
10 + 5
# Out:
# 15

# %%
10 / 5
# Out:
# 2.0

# %%
10 // 5
# Out:
# 2

# %%
10 * 5
# Out:
# 50

# %%
_
# Out:
# 50

# %%
3 * 2
# Out:
# 6

# %%
3 ** 2
# Out:
# 9

# %%
10 % 5
# Out:
# 0

# %%
2 + 3
10 - 3
10 * 3
10 / 3
# Out:
# 3.3333333333333335

# %%
print(2+3)
print(10-3)
# Out:
# 5
# 7

# %%
print(10*3)
print(10/3)
# Out:
# 30
# 3.3333333333333335

# %% [markdown]
# ## Work with Text

# %%
apple
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 apple
#
# NameError: name 'apple' is not defined

# %%
'apple'
# Out:
# 'apple'

# %%
"apple"
# Out:
# 'apple'

# %%
'''apple'''
# Out:
# 'apple'

# %%
'apple
fruit
is
good for health'
# Out:
#   Cell In[23], line 1
#     'apple
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"apple
fruit
is
good for health"
# Out:
#   Cell In[26], line 1
#     "apple
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''apple
fruit
is
good for health'''
# Out:
# 'apple\nfruit\nis\ngood for health'

# %%
v = 5

# %%
id(v)
# Out:
# 140730217085496

# %%
nit = 25
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 nit = 25
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
1nit = 30
1nit
# Out:
#   Cell In[31], line 1
#     1nit = 30
#     ^
# SyntaxError: invalid decimal literal

# %%
nit1 = 30
nit1
# Out:
# 30

# %%
23a = 56
23a
# Out:
#   Cell In[33], line 1
#     23a = 56
#      ^
# SyntaxError: invalid decimal literal

# %%
var@ = 56
# Out:
#   Cell In[34], line 1
#     var@ = 56
#          ^
# SyntaxError: invalid syntax

# %%
var_ = 6

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
for = 4 
for
# Out:
#   Cell In[37], line 1
#     for = 4
#         ^
# SyntaxError: invalid syntax

# %%
For = 3
For
# Out:
# 3

# %% [markdown]
# 1. Case Sensitive
# 2. does not start with digit but end with digit
# 3. keyword not define as variable
# 4. special character are not allowed
