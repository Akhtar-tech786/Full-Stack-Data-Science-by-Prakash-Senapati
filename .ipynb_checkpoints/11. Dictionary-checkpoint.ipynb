# %% [markdown]
# ## ****Dictionary**** Another Data Structure

# %%
d = {}

# %%
d
# Out:
# {}

# %%
type(d)
# Out:
# dict

# %%
d1 = {1:'one',2:'two',3:'three'}

# %%
d1
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
d2 = {'one':1,'two':2,'three':3}
d2
# Out:
# {'one': 1, 'two': 2, 'three': 3}

# %%
d2.keys()
# Out:
# dict_keys(['one', 'two', 'three'])

# %%
d2.values()
# Out:
# dict_values([1, 2, 3])

# %%
d2.items()
# Out:
# dict_items([('one', 1), ('two', 2), ('three', 3)])

# %%
len(d2)
# Out:
# 3

# %%
my_dict = {1:'one',2:'two',3:'three','A':['Asif','John','Maria']}
my_dict
# Out:
# {1: 'one', 2: 'two', 3: 'three', 'A': ['Asif', 'John', 'Maria']}

# %%
my_dict = {1:'one',2:'two','A':['Asif','john','Maria'],'B':['Bat','Cat','Dog']}
my_dict
# Out:
# {1: 'one',
#  2: 'two',
#  'A': ['Asif', 'john', 'Maria'],
#  'B': ['Bat', 'Cat', 'Dog']}

# %%
my_dict = {1:'one',2:'two','A':{'Name':'Asif','Age':'20'},'B':['Bat','Cat','Dog']}
my_dict
# Out:
# {1: 'one',
#  2: 'two',
#  'A': {'Name': 'Asif', 'Age': '20'},
#  'B': ['Bat', 'Cat', 'Dog']}

# %%
keys = {'a','b','c','d'}
mydict2 = dict.fromkeys(keys)   # create a dictionary from a sequence of keys
mydict2
# Out:
# {'d': None, 'c': None, 'a': None, 'b': None}

# %%
keys = {'a','b','c','d'}
value = 10
mydict3 = dict.fromkeys(keys, value)   # create a dictionary from a sequence of keys and value
mydict3
# Out:
# {'d': 10, 'c': 10, 'a': 10, 'b': 10}

# %%
keys = {'a','b','c','d'}
value = [10,20,30]
mydict4 = dict.fromkeys(keys, value)   # create a dictionary from a sequence of keys
mydict4
# Out:
# {'d': [10, 20, 30], 'c': [10, 20, 30], 'a': [10, 20, 30], 'b': [10, 20, 30]}

# %%
value.append(40)
mydict4
# Out:
# {'d': [10, 20, 30, 40],
#  'c': [10, 20, 30, 40],
#  'a': [10, 20, 30, 40],
#  'b': [10, 20, 30, 40]}

# %% [markdown]
# #### Accesing Items

# %%
mydict = {1:'one',2:'two',3:'three',4:'four'}
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
mydict[1]
# Out:
# 'one'

# %%
mydict.get(1) # access item using get method
# Out:
# 'one'

# %%
mydict1 = {'Name':'Asif','ID':74321,'DOB':1991,'Job':'Analyst'}
mydict1
# Out:
# {'Name': 'Asif', 'ID': 74321, 'DOB': 1991, 'Job': 'Analyst'}

# %%
mydict1['Name'] # Access item using key
# Out:
# 'Asif'

# %%
mydict1.get('Job')
# Out:
# 'Analyst'

# %% [markdown]
# #### Add, Remove, Change Items

# %%
mydict1 = {'Name':'Asif','ID':74321,'DOB':1991,'Address':'Helsinki'}
mydict1
# Out:
# {'Name': 'Asif', 'ID': 74321, 'DOB': 1991, 'Address': 'Helsinki'}

# %%
mydict1['DOB'] = 1992 # Changing dictionary items
mydict1['Address'] = 'Delhi'
mydict1
# Out:
# {'Name': 'Asif', 'ID': 74321, 'DOB': 1992, 'Address': 'Delhi'}

# %%
mydict1['Job'] = 'Analyst'
mydict1
# Out:
# {'Name': 'Asif',
#  'ID': 74321,
#  'DOB': 1992,
#  'Address': 'Delhi',
#  'Job': 'Analyst'}

# %%
mydict1.pop('Job') # removing items in the dictionary using pop method
mydict1
# Out:
# {'Name': 'Asif', 'ID': 74321, 'DOB': 1992, 'Address': 'Delhi'}

# %%
mydict1.popitem()  # a random item is removed
# Out:
# ('Address', 'Delhi')

# %%
mydict1
# Out:
# {'Name': 'Asif', 'ID': 74321, 'DOB': 1992}

# %%
del[mydict1['ID']]  # removing item using del method
mydict1
# Out:
# {'Name': 'Asif', 'DOB': 1992}

# %%
mydict1.clear()  # delete all items of the dictionary using clear method
mydict1
# Out:
# {}

# %%
del mydict1 # deleting the dictionary object

# %%
mydict1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 mydict1
#
# NameError: name 'mydict1' is not defined

# %% [markdown]
# #### Copy Dictionary

# %%
mydict={'Name':'Asif','ID':12345,'DOB':1991,'Address':'Hilsinki'}
mydict
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
mydict1=mydict# Create a new reference "mydict1"

# %%
id(mydict),id(mydict1)# Theaddress of bothmydict &mydict1 will be the same
# Out:
# (3098405877888, 3098405877888)

# %%
mydict2=mydict.copy()#Create a copyof the dictionary

# %%
id(mydict2)
# Out:
# 3098405909248

# %%
mydict['Address']='Mumbai'

# %%
mydict
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Mumbai'}

# %%
mydict1# mydict1 will be also impacted as it is pointing to the same dictionary
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Mumbai'}

# %%
mydict2# Copy of list won't be impacted due to the changes made in the original
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %% [markdown]
# #### Loop through a Dictionary

# %%
mydict1 = {'Name':'Asif','ID':12345,'DOB':1991,'Address':'Hilsinki','Job':'Analyst'}
mydict1
# Out:
# {'Name': 'Asif',
#  'ID': 12345,
#  'DOB': 1991,
#  'Address': 'Hilsinki',
#  'Job': 'Analyst'}

# %%
for i in mydict1:
    print(i,':',mydict1[i])  #Key &value pair
# Out:
# Name : Asif
# ID : 12345
# DOB : 1991
# Address : Hilsinki
# Job : Analyst

# %%
for i in mydict1:
    print(mydict1[i]) #Dictionaryitems
# Out:
# Asif
# 12345
# 1991
# Hilsinki
# Analyst

# %% [markdown]
# #### Dictionary Membership

# %%
mydict1={'Name':'Asif','ID':12345,'DOB':1991,'Job':'Analyst'} 
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Job': 'Analyst'}

# %%
'Name' in mydict1# Test if a key is in a dictionary or not.
# Out:
# True

# %%
'Asif'in mydict1# Membership test can be only done for keys.
# Out:
# False

# %%
'ID'in mydict1
# Out:
# True

# %%
'Address'in mydict1
# Out:
# False

# %% [markdown]
# ****All / Any****
#
# The ****all()**** method returns:
#
#  - True - If all all keys of the dictionary are true
#  - False - If any key of the dictionary is false
#
# The ****any()**** function returns True if any key of the dictionary is True.If not, any() returns False.

# %%
mydict1={'Name':'Asif','ID':12345,'DOB':1991,'Job':'Analyst'}
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Job': 'Analyst'}

# %%
all(mydict1)# Will Returnfalse as one valueis false (Value 0)
# Out:
# True

# %% [markdown]
# ### Completed
